# %%
import pandas as pd
base_ner=pd.read_csv("C:/Users/SekouDRAME/Desktop/MES_DOSSIERS_AS/AS3_2024_2025/SEMESTRE_1/OPTION_DATA_SCIENCE/NLP/projet_nlp_ner_2025/projet_nlp_ner_2025/data/raw/NER_dataset.csv",sep=",",encoding="latin1")

# %%
base_ner.head(20)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1           NaN             of   IN      O
# 2           NaN  demonstrators  NNS      O
# 3           NaN           have  VBP      O
# 4           NaN        marched  VBN      O
# 5           NaN        through   IN      O
# 6           NaN         London  NNP  B-geo
# 7           NaN             to   TO      O
# 8           NaN        protest   VB      O
# 9           NaN            the   DT      O
# 10          NaN            war   NN      O
# 11          NaN             in   IN      O
# 12          NaN           Iraq  NNP  B-geo
# 13          NaN            and   CC      O
# 14          NaN         demand   VB      O
# 15          NaN            the   DT      O
# 16          NaN     withdrawal   NN      O
# 17          NaN             of   IN      O
# 18          NaN        British   JJ  B-gpe
# 19          NaN         troops  NNS      O

# %%
base_ner['Tag'].unique()
#len(list(base_ner['Tag'].unique()))
# Out:
# array(['O', 'B-geo', 'B-gpe', 'B-per', 'I-geo', 'B-org', 'I-org', 'B-tim',
#        'B-art', 'I-art', 'I-per', 'I-gpe', 'I-tim', 'B-nat', 'B-eve',
#        'I-eve', 'I-nat'], dtype=object)

# %%
len(list(base_ner['Tag'].unique()))
# Out:
# 17

# %%
base_ner.describe
base_ner['Sentence #'].unique()
#len(list(base_ner['Sentence #'].unique()))
# Out:
# array(['Sentence: 1', nan, 'Sentence: 2', ..., 'Sentence: 47957',
#        'Sentence: 47958', 'Sentence: 47959'], dtype=object)

# %%
# Grouper les données par phrase
sentences = []

for _, group in base_ner.groupby("Sentence #"):
    sentence = [(word, tag) for word, tag in zip(group["Word"], group["Tag"])]
    sentences.append(sentence)
# Out:
# [('Thousands', 'O')]

# %%
# Exemple : afficher la première phrase avec ses tags
print(sentences[0])
sentences
len(sentences)
# Out:
# [('Thousands', 'O')]
# 47959
